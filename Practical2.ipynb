# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"StudentPerformance.csv")
print(df)
# Out:
#     math score  reading score  writing score  placement score  \
# 0         77.0           78.0           66.0             83.0
# 1         79.0           78.0           68.0             81.0
# 2         70.0           89.0           73.0             92.0
# 3         79.0           75.0           69.0             99.0
# 4         66.0            NaN           80.0             95.0
# 5         80.0           82.0           80.0             82.0
# 6         61.0           80.0           64.0             75.0
# 7         68.0           80.0           79.0             95.0
# 8         64.0           92.0           61.0             80.0
# 9         69.0           86.0           70.0             99.0
# 10        73.0           83.0           73.0             97.0
# 11        62.0           91.0            NaN             94.0
# 12        76.0           86.0           68.0             92.0
# 13         NaN           84.0           61.0             86.0
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score  placement score  \
# count   29.000000      28.000000      29.000000        29.000000
# mean    71.103448      86.107143      71.068966        87.862069
# std      6.757772       5.293877       9.516643         7.735466
# min     60.000000      75.000000      60.000000        75.000000
# 25%     66.000000      82.750000      66.000000        81.000000
# 50%     71.000000      86.000000      69.000000        86.000000
# 75%     77.000000      90.250000      73.000000        95.000000
# max     80.000000      94.000000     110.000000        99.000000
#
#        club join date   placement offer count
# count        29.000000              28.000000
# mean       2021.034483               2.535714
# std          10.489732               1.290482
# min        2015.000000               0.000000
# 25%        2018.000000               2.000000
# 50%        2019.000000               2.000000
# 75%        2021.000000               3.000000
# ...

# %%
df.describe().sum
# Out:
# <bound method DataFrame.sum of        math score  reading score  writing score  placement score  \
# count   29.000000      28.000000      29.000000        29.000000
# mean    71.103448      86.107143      71.068966        87.862069
# std      6.757772       5.293877       9.516643         7.735466
# min     60.000000      75.000000      60.000000        75.000000
# 25%     66.000000      82.750000      66.000000        81.000000
# 50%     71.000000      86.000000      69.000000        86.000000
# 75%     77.000000      90.250000      73.000000        95.000000
# max     80.000000      94.000000     110.000000        99.000000
#
#        club join date   placement offer count
# count        29.000000              28.000000
# mean       2021.034483               2.535714
# std          10.489732               1.290482
# min        2015.000000               0.000000
# 25%        2018.000000               2.000000
# 50%        2019.000000               2.000000
# ...

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  placement score  \
# 0        False          False          False            False
# 1        False          False          False            False
# 2        False          False          False            False
# 3        False          False          False            False
# 4        False           True          False            False
# 5        False          False          False            False
# 6        False          False          False            False
# 7        False          False          False            False
# 8        False          False          False            False
# 9        False          False          False            False
# 10       False          False          False            False
# 11       False          False           True            False
# 12       False          False          False            False
# 13        True          False          False            False
# ...

# %%
df.notnull()
# Out:
#     math score  reading score  writing score  placement score  \
# 0         True           True           True             True
# 1         True           True           True             True
# 2         True           True           True             True
# 3         True           True           True             True
# 4         True          False           True             True
# 5         True           True           True             True
# 6         True           True           True             True
# 7         True           True           True             True
# 8         True           True           True             True
# 9         True           True           True             True
# 10        True           True           True             True
# 11        True           True          False             True
# 12        True           True           True             True
# 13       False           True           True             True
# ...

# %%
df.describe().isnull
# Out:
# <bound method DataFrame.isnull of        math score  reading score  writing score  placement score  \
# count   29.000000      28.000000      29.000000        29.000000
# mean    71.103448      86.107143      71.068966        87.862069
# std      6.757772       5.293877       9.516643         7.735466
# min     60.000000      75.000000      60.000000        75.000000
# 25%     66.000000      82.750000      66.000000        81.000000
# 50%     71.000000      86.000000      69.000000        86.000000
# 75%     77.000000      90.250000      73.000000        95.000000
# max     80.000000      94.000000     110.000000        99.000000
#
#        club join date   placement offer count
# count        29.000000              28.000000
# mean       2021.034483               2.535714
# std          10.489732               1.290482
# min        2015.000000               0.000000
# 25%        2018.000000               2.000000
# 50%        2019.000000               2.000000
# ...

# %%
df.isnull().sum()
# Out:
# math score               1
# reading score            2
# writing score            1
# placement score          1
# club join date           1
# placement offer count    2
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
col = ['math score','writing score','placement score','placement offer count']
df.boxplot(col)
plt.show()

# %%
print(np.where(df['math score']>90))
print(np.where(df['placement score']<25))
print(np.where(df['writing score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
pip install scipy
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 320.0 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 388.9 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 404.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/40.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/40.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/40.9 MB 1.7 MB/s eta 0:00:24
#    ---------------------------------------- 0.2/40.9 MB 2.3 MB/s eta 0:00:18
#    ---------------------------------------- 0.3/40.9 MB 2.5 MB/s eta 0:00:17
#     --------------------------------------- 0.6/40.9 MB 3.0 MB/s eta 0:00:14
#     --------------------------------------- 0.7/40.9 MB 3.2 MB/s eta 0:00:13
# ...

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score']))
print(z)
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]

# %%
threshold = 0.18
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([], dtype=int64),)

# %%
sorted_wscore= sorted(df['math score'])
sorted_wscore
# Out:
# [60.0,
#  60.0,
#  61.0,
#  61.0,
#  62.0,
#  64.0,
#  65.0,
#  66.0,
#  68.0,
#  68.0,
#  68.0,
#  69.0,
#  69.0,
#  70.0,
#  71.0,
#  73.0,
#  73.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  78.0,
#  79.0,
#  79.0,
#  80.0,
#  nan,
#  79.0,
#  80.0,
#  80.0]

# %%
q1 = np.percentile(sorted_wscore, 25)
q3=np.percentile(sorted_wscore,75)
print(q1,q3)
# Out:
# nan nan

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# nan nan

# %%
r_outliers = []
for i in sorted_wscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %%
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(df['placement score'], df['placement offer count'])
plt.show()
